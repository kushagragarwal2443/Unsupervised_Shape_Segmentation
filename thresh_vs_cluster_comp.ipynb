# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
shapes_reps_1 = np.load("p7_ShapeReps_246x3.npy")
shapes_dist_euc1 = np.load("p7_ShapeDist_6144_Euc.npy")

shapes_reps_2 = np.load("p46_ShapeReps_198x3.npy")
shapes_dist_euc2 = np.load("p46_ShapeDist_6144_Euc.npy")

# %% [markdown]
# ## Main functions

# %%
def get_silhouette_score(cluster1, shape_reps):
    
    thresh_labels = np.zeros(len(shape_reps), dtype=int)
    
    for i in range(len(thresh_labels)):
    
        if(i in cluster1):
            thresh_labels[i] = 1
        else:
            thresh_labels[i] = 0
    
    score = silhouette_score(shape_reps, thresh_labels, metric='euclidean')
    return score

def get_fitness(population, dist):
    pop_size = len(population)
    fitness_vec = []
    for pop in range(pop_size):
        a = list(population[pop])
        length = len(a)
        total_distance = 0
        for i in range(length):
            for j in range(i+1, length):
                total_distance += dist[a[i]][a[j]]
        total_pairs = length*((length-1)/2.0)
        fitness_vec.append(total_pairs/total_distance) ## inverse of avg distance
    return fitness_vec

def get_fitness_KnearestNeighbour(population, dist, knn):
    pop_size = len(population)
    fitness_vec = []
    for pop in range(pop_size):
        a = list(population[pop])
        length = len(a)
        if(knn > (length-1) or knn<1):
            print("Choose an appropriate K-NN value -> [1, number of roots - 1]")
            return -1
        total_distance = 0
        for i in range(length):
            cur_distance = []
            for j in range(length):
                if(i!=j):
                    cur_distance.append(dist[a[i]][a[j]])
#             print("\nNEW ELEMENT")
#             print(cur_distance)
#             print("SORTING....")
            cur_distance = np.sort(np.array(cur_distance))
#             print(cur_distance)
            cur_closest_distance = np.sum(cur_distance[:knn])/knn
#             print("AVERAGE CLOSEST DISTANCE", cur_closest_distance)
            total_distance += cur_closest_distance
#             print("TOTAL DISTANCE TILL NOW", total_distance)
#         print("LENGTH", length)
#         print(length/total_distance)
        fitness_vec.append(length/total_distance) ## inverse of avg nearest neighbour distance
    return fitness_vec

# %% [markdown]
# ## Defining best clusters

# %%
best_cluster1_nc2 = [236, 212, 154, 155, 123, 185, 238, 239, 100, 134, 132, 65, 167, 97, 63, 131, 129, 159, 191, 217, 158, 92, 235, 205, 113, 45, 231, 179, 180, 174, 226, 225, 228, 204, 198, 171, 169, 196]
best_cluster1_k1 = [123, 164, 194, 65, 163, 188, 125, 218, 244, 159, 68, 167, 193, 63, 245, 145, 186, 148, 49, 48, 52, 233, 183, 171, 140, 201, 203, 204, 205, 109, 238, 239, 155, 196, 137, 170, 207, 45]
best_cluster1_k3 = [156, 123, 238, 239, 185, 154, 155, 196, 223, 197, 212, 116, 150, 205, 233, 115, 146, 45, 142, 201, 199, 225, 231, 228, 229, 163, 191, 245, 65, 158, 190, 92, 164, 167, 134, 165, 193, 63]
best_cluster1_k5 = [245, 193, 63, 134, 167, 163, 165, 164, 65, 223, 171, 169, 225, 196, 173, 174, 228, 204, 185, 212, 238, 239, 182, 116, 180, 208, 145, 205, 146, 45, 154, 155, 188, 125, 158, 159, 123, 191]
best_cluster1_k7 = [196, 171, 169, 198, 225, 188, 158, 123, 155, 154, 125, 174, 205, 203, 204, 226, 145, 149, 180, 208, 146, 45, 212, 238, 239, 182, 185, 163, 245, 65, 191, 159, 167, 164, 165, 134, 193, 63]

# %%
best_cluster2_nc2 = [80, 52, 176, 50, 101, 126, 150, 149, 136, 158, 159, 133, 137, 115, 163, 138, 132, 155, 142, 167, 39, 168, 145, 123, 147, 43, 141, 65, 121]
best_cluster2_k1 = [97, 73, 42, 71, 41, 189, 92, 67, 116, 65, 137, 185, 139, 43, 152, 48, 125, 78, 79, 22, 105, 162, 160, 58, 180, 133, 55, 106]
best_cluster2_k3 = [74, 92, 67, 185, 73, 123, 43, 41, 71, 121, 189, 141, 65, 152, 48, 77, 79, 105, 78, 155, 107, 133, 158, 139, 162, 159, 161, 86]
best_cluster2_k5 = [97, 149, 101, 50, 74, 147, 43, 176, 105, 79, 189, 191, 69, 140, 141, 65, 142, 167, 67, 139, 137, 138, 31, 159, 158, 131, 179, 133, 100]
best_cluster2_k7 = [176, 79, 77, 101, 100, 105, 131, 132, 158, 138, 137, 31, 159, 133, 139, 115, 141, 65, 142, 167, 39, 149, 74, 97, 147, 43, 191, 189, 145]

# %% [markdown]
# # p7 Silhouette Scores

# %%
print("thresh 600:", get_silhouette_score(range(0,34), shapes_reps_1))
print("thresh 700:", get_silhouette_score(range(34,70), shapes_reps_1))
print("thresh 800:", get_silhouette_score(range(70,103), shapes_reps_1))
print("thresh 900:", get_silhouette_score(range(103,136), shapes_reps_1))
print("thresh 1000:", get_silhouette_score(range(136,168), shapes_reps_1))
print("thresh 1100:", get_silhouette_score(range(168,196), shapes_reps_1))
print("thresh 1200:", get_silhouette_score(range(196,221), shapes_reps_1))
print("thresh 1300:", get_silhouette_score(range(221,246), shapes_reps_1))
# Out:
# thresh 600: 0.22359873781876866
# thresh 700: 0.012789307665158072
# thresh 800: -0.01693653359869221
# thresh 900: -0.04910735850548752
# thresh 1000: -0.016527439278272264
# thresh 1100: -0.018035829963198677
# thresh 1200: -0.03965883350834118
# thresh 1300: 0.026794170110399394

# %%
print("best_cluster1_nc2:", get_silhouette_score(best_cluster1_nc2, shapes_reps_1))
print("best_cluster1_k1:", get_silhouette_score(best_cluster1_k1, shapes_reps_1))
print("best_cluster1_k3:", get_silhouette_score(best_cluster1_k3, shapes_reps_1))
print("best_cluster1_k5:", get_silhouette_score(best_cluster1_k5, shapes_reps_1))
print("best_cluster1_k7:", get_silhouette_score(best_cluster1_k7, shapes_reps_1))
# Out:
# best_cluster1_nc2: -0.0270534362561036
# best_cluster1_k1: 0.003432339508632861
# best_cluster1_k3: 0.0006176156209702188
# best_cluster1_k5: -0.0011293684273598638
# best_cluster1_k7: -0.004445670712435029

# %% [markdown]
# # Scores using fitness

# %% [markdown]
# ## P7

# %%
print("Nc2")
print("Best cluster", 1/(get_fitness(np.expand_dims(np.array(best_cluster1_nc2),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(0,34)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(34,70)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(70,103)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(103,136)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(136,168)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(168,196)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(196,221)),axis=0), shapes_dist_euc1)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(221,246)),axis=0), shapes_dist_euc1)[0]))
print()

print("1nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster1_k1),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,34)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(34,70)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(70,103)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(103,136)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(136,168)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(168,196)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(196,221)),axis=0), shapes_dist_euc1, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(221,246)),axis=0), shapes_dist_euc1, 1)[0]))
print()

print("3nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster1_k3),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,34)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(34,70)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(70,103)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(103,136)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(136,168)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(168,196)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(196,221)),axis=0), shapes_dist_euc1, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(221,246)),axis=0), shapes_dist_euc1, 3)[0]))
print()

print("5nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster1_k5),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,34)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(34,70)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(70,103)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(103,136)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(136,168)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(168,196)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(196,221)),axis=0), shapes_dist_euc1, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(221,246)),axis=0), shapes_dist_euc1, 5)[0]))
print()

print("7nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster1_k7),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,34)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(34,70)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(70,103)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(103,136)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(136,168)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(168,196)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(196,221)),axis=0), shapes_dist_euc1, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(221,246)),axis=0), shapes_dist_euc1, 7)[0]))
# Out:
# Nc2
# Best cluster 201.26883678832706
# 315.477709171476
# 314.62012210071106
# 298.8297375643712
# 295.6453262100018
# 295.51889502774907
# 297.4513669131202
# 244.05212993066854
# 244.4343923706455
#
# 1nn
# Best cluster 36.65190519863082
# 82.52533356746225
# 65.32412520013939
# 62.47889983880003
# 65.16917636417463
# 58.96050690086407
# 67.52812053301999
# 54.76454878732754
# 61.509272565835595
#
# 3nn
# Best cluster 51.877655816362214
# 103.63868541764319
# 81.3969870700757
# 79.89895818881426
# 85.65159181101745
# 80.14564719473628
# 90.69038562706253
# 74.14517610244722
# 75.38384020733261
#
# 5nn
# Best cluster 60.60649115971083
# 121.80904225383021
# 97.4305874902421
# 93.9336619487387
# 101.40274460039308
# 96.82773513968709
# 107.07309572347586
# 90.41389354750976
# 89.92806802014373
#
# 7nn
# Best cluster 68.89879332152674
# 138.10488006357798
# 111.20753367225154
# 107.08218621837321
# 114.83499453698359
# 111.49749807996442
# 121.06964946504407
# 104.81816960997513
# ...

# %% [markdown]
# ## P46

# %%
print("Nc2")
print("Best cluster", 1/(get_fitness(np.expand_dims(np.array(best_cluster2_nc2),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(0,26)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(26,54)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(54,81)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(81,106)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(106,131)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(131,155)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(155,178)),axis=0), shapes_dist_euc2)[0]))
print(1/(get_fitness(np.expand_dims(np.array(range(178,198)),axis=0), shapes_dist_euc2)[0]))
print()

print("1nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster2_k1),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,26)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(26,54)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(54,81)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(81,106)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(106,131)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(131,155)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(155,178)),axis=0), shapes_dist_euc2, 1)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(178,198)),axis=0), shapes_dist_euc2, 1)[0]))
print()

print("3nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster2_k3),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,26)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(26,54)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(54,81)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(81,106)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(106,131)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(131,155)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(155,178)),axis=0), shapes_dist_euc2, 3)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(178,198)),axis=0), shapes_dist_euc2, 3)[0]))
print()

print("5nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster2_k5),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,26)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(26,54)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(54,81)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(81,106)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(106,131)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(131,155)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(155,178)),axis=0), shapes_dist_euc2, 5)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(178,198)),axis=0), shapes_dist_euc2, 5)[0]))
print()

print("7nn")
print("Best cluster", 1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(best_cluster2_k7),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(0,26)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(26,54)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(54,81)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(81,106)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(106,131)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(131,155)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(155,178)),axis=0), shapes_dist_euc2, 7)[0]))
print(1/(get_fitness_KnearestNeighbour(np.expand_dims(np.array(range(178,198)),axis=0), shapes_dist_euc2, 7)[0]))
# Out:
# Nc2
# Best cluster 270.57767401842057
# 470.73467122362104
# 393.15175747500984
# 375.9407312698665
# 376.3851691467503
# 346.01086965895973
# 301.43124753528735
# 305.8530174561709
# 357.689885261034
#
# 1nn
# Best cluster 52.062228778436186
# 141.11767729904554
# 107.89326330430407
# 86.04565542407494
# 104.42953928563861
# 98.82725849755285
# 88.70433238698494
# 84.95041391054562
# 104.54193382373369
#
# 3nn
# Best cluster 76.70951441943777
# 170.27106185159823
# 129.91503264746632
# 110.03927077224024
# 125.58520083964903
# 117.86382108298716
# 106.00721633451204
# 108.73369060596131
# 124.8811469884485
#
# 5nn
# Best cluster 92.96997269774653
# 190.829053616542
# 145.54098303010085
# 127.68528654437252
# 143.26991731732036
# 134.91791222030872
# 120.04362103510498
# 127.30446926125029
# 153.63726940319953
#
# 7nn
# Best cluster 104.66908636346488
# 209.68590411479687
# 161.32019677149015
# 145.45647666725216
# 161.38166757823865
# 151.60434049556756
# 135.58104615914962
# ...
